# %%
import pandas as pd

# %%
df = pd.read_csv("taxi_trip_pricing.csv")

# %%
df['Trip_Price']
# Out:
# 0      36.2624
# 1          NaN
# 2      52.9032
# 3      36.4698
# 4      15.6180
#         ...
# 995    34.4049
# 996    62.1295
# 997    33.1236
# 998    61.2090
# 999    45.4437
# Name: Trip_Price, Length: 1000, dtype: float64

# %%
تمرین ۱:

ابتدا داده زیر را به صورت اماری و نموداری بررسی کنید
سپس درباره تابع LabelEncoder تحقیق کنید
با استفاده از مطالب تحقیق شده داده را برای اموزش مدل اماده کنید
بر روی ستون Trip_Price یک مدل رگریسون را با استفاده از SVR, RandomForestRegressor اموزش دهید
# Out:
#   Cell In[7], line 1
#     ابتدا داده زیر را به صورت اماری و نموداری بررسی کنید
#           ^
# SyntaxError: invalid syntax

# %%
تمرین ۲:

داده تصاویر دست نویس mnist را لود کنید
سپس با استفاده از PCA تصاویر را از ۷۲۸ بعد بع ۲۰۰ بعد کاهش دهید
بر روی داده یک DecisionTreeClasifier, RandomForestClassifier اموزش دهید.
سعی کنید دقت مدل را افزایش دهید
# Out:
#   Cell In[8], line 1
#     تمرین ۲:
#           ^
# SyntaxError: invalid character '۲' (U+06F2)
