# %% [markdown]
# ## Deep Learning Era

# %% [markdown]
# ### RNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras.datasets import imdb
import numpy as np
# Out:
# 2025-04-01 12:00:42.123141: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
(train, train_y), (test, test_y) = imdb.load_data(num_words=10000)

# %%
np.unique(train_y)
# Out:
# array([0, 1])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences


train = pad_sequences(train, 3000)
test = pad_sequences(test, 3000)
print(train.shape, test.shape)
# Out:
# (25000, 3000) (25000, 3000)

# %%
model = Sequential(
    [
        SimpleRNN(64, activation='tanh', input_shape=(3000, 1)),
        Dense(1, activation='sigmoid')
    ]
)

model.compile(optimizer='adam', loss='binarycategorical_crossentropy', metrics=['accuracy'])
# Out:
# 2025-04-01 12:00:56.518534: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 64)                4224
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 4,289
# Trainable params: 4,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics='accuracy')

# %%
history = model.fit(
    train,
    train_y,
    epochs=10,
    validation_split=.1,
    batch_size=32,
    shuffle=True
)
# Out:
# Epoch 1/10
# 704/704 [==============================] - 2756s 4s/step - loss: 0.6962 - accuracy: 0.4994 - val_loss: 0.6965 - val_accuracy: 0.4960
# Epoch 2/10
# 704/704 [==============================] - 2217s 3s/step - loss: 0.6954 - accuracy: 0.5008 - val_loss: 0.6938 - val_accuracy: 0.5120
# Epoch 3/10
# 704/704 [==============================] - 1418s 2s/step - loss: 0.6947 - accuracy: 0.5052 - val_loss: 0.6946 - val_accuracy: 0.5056
# Epoch 4/10
# 704/704 [==============================] - 1506s 2s/step - loss: 0.6942 - accuracy: 0.5060 - val_loss: 0.6949 - val_accuracy: 0.4980
# Epoch 5/10
# 704/704 [==============================] - 1919s 3s/step - loss: 0.6942 - accuracy: 0.5048 - val_loss: 0.6923 - val_accuracy: 0.5172
# Epoch 6/10
# 538/704 [=====================>........] - ETA: 6:49 - loss: 0.6937 - accuracy: 0.5057

# %% [markdown]
# ## Trianing with GRU

# %% [markdown]
# ## Trainig With LSTM
